# %% [markdown]
# # **Hello World**
#
# ## ***Smaller Hello World***
#
# this is a regular paragraph, today I'm learning `python`.
#
# - item1
# - item2
# - item3
#
# ```
# ## hello world program
# print("hello world")
#
# ## please see the markdown syntax
# https://www.markdownguide.org/basic-syntax/#images-1
# ```

# %% [markdown]
# # **Python Programming 101**
#
# - variables
# - data types
# - data structures
# - function
# - control flow

# %%
# basic expression / calculation

print(1+1)
print(2*2)
print(10/3)
print(10//3)
# Out:
# 2
# 4
# 3.3333333333333335
# 3

# %%
## power exponent
print(5**2)
print(pow(3,2))
print(abs(-5))
# Out:
# 25
# 9
# 5

# %%
## compare values
1+1 != 2
# Out:
# False

# %%
(1+5)*2/3 == 4
# Out:
# True

# %%
## python > R
## deep learning => AI software
## software + API, ML

# %%
## 1. variables

my_name = "Kang"
salary_2023 = 50000
_ = "Kang" # Able to use underscoll to assign the value

income = 50000
expense = 36000
saving = income - expense
print(saving)

my_name = "john doe"
print(my_name)
# Out:
# 14000
# john doe

# %%
## delete variable
del saving

# %%
## print string
my_name = "Kang"
age = 23
fav_lang = "R"

# %%
## fstring
## string template
f"Hi my name is {my_name} and I'm {age} years old and my favorite language is {fav_lang}."
# Out:
# "Hi my name is Kang and I'm 23 years old and my favorite language is R."

# %%
## traditional way to create template
my_name = "Kang"
"Hi my name is {}". format(my_name)
# Out:
# 'Hi my name is Kang'

# %%
## string + string
## string *3

text = "blackpink" + " in your area!"

text2 = "blackpink" * 3

# %%
print(text)
print(text2)
# Out:
# blackpink in your area!
# blackpinkblackpinkblackpink

# %%
len(text)
# Out:
# 23

# %%
## data types
## 1. int
## 2. float
## 3. str
## 4. bool: True False // TRUE FALSE in R
## python/r is case sensitive

# %%
x = "I\"m learning Python"
print(x, type(x))
# Out:
# I"m learning Python <class 'str'>

# %%
## newline character \n
## tab \t character
print("Hello\nWorld!")
print("Hello\tWorld!")
# Out:
# Hello
# World!
# Hello	World!

# %%
poem = """hello world
I'm learning python
and it's similar to R"""

print(poem)
# Out:
# hello world
# I'm learning python
# and it's similar to R

# %%
## convert data type
## int() float() str() bool()

x = "100"
print(x, type(x))

x = int(x)
print(x, type(x))
# Out:
# 100 <class 'str'>
# 100 <class 'int'>

# %%
bool(0)
# Out:
# False

# %%
## get input from user

user_name = input("What's your username: ")
print("Hi! " + user_name)

user_age = input("How old are you? ")
print("Your age: " + user_age) # now user_age type is str
print(int(user_age) *2)
# Out:
# What's your username: Lisa
# Hi! Lisa
# How old are you? 25
# Your age: 25
# 50

# %%
## data type
x = 100
print(x, type(x))
# Out:
# 100 <class 'int'>

# %%
## type hint: just guide the valuable to be what type but what type is assign to it is first priority
age: int = "20"
print(age, type(age))
# Out:
# 20 <class 'str'>

# %%
gpa: float = 3.5
print(gpa, type(float))
print(gpa, type(gpa))
# Out:
# 3.5 <class 'type'>
# 3.5 <class 'float'>

# %%
university: str  = "Manchester"
print(university, type(university))
# Out:
# Manchester <class 'str'>

# %%
## define a new function

def add_two_num(val1, val2):
    return val1+val2

# %%
result = add_two_num(5,10)
print(result)
# Out:
# 15

# %%
## default argument
def greeting(name = "kang", food = "KFC"):
    return f"Hello! {name}. I like {food}."

# %%
greeting(food = "McDonalds", name = "Lisa")
# Out:
# 'Hello! Lisa. I like McDonalds.'

# %%
## function get input from user
def greeting_v2():
    name = input("What's your name?")
    return f"Hello {name}!"

# %%
greeting_v2()
# Out:
# What's your name?Kang
# 'Hello Kang!'

# %%
## function that return multiple values
def demo():
    name1 = input("Pick a name: ")
    name2 = input("Pick a name: ")
    return (name1, name2, 100) # tupple

# %%
demo()
# Out:
# Pick a name: John Doe
# Pick a name: Lisa BP
# ('John Doe', 'Lisa BP', 100)

# %%
## tuple unpacking
friend1, friend2, _ = demo()
# Out:
# Pick a name: John Doe
# Pick a name: Lisa BP

# %%
print(friend1, friend2)
# Out:
# John Doe Lisa BP

# %%
## 4. data structure
## 4.1 list
## 4.2 tuple
## 4.3 dictionary
## 4.4 set

# %%
## list => use square bracket [ ... ] and Able to use differnet type of data ex. str and int
shopping_list = ["banana", "egg", "bread", 100]

# %%
shopping_list
# Out:
# ['banana', 'egg', 'bread', 100]

# %%
## method list.append() => add something into list
shopping_list.append("noddle")

# %%
shopping_list
# Out:
# ['banana', 'egg', 'bread', 100, 'noddle']

# %%
shopping_list.append("orange")

# %%
shopping_list
# Out:
# ['banana', 'egg', 'bread', 100, 'noddle', 'orange']

# %%
shopping_list.insert(0, "grape") # select which index to insert with new value

# %%
shopping_list
# Out:
# ['grape', 'banana', 'egg', 'bread', 100, 'noddle', 'orange']

# %%
## update value5 if we know the index
shopping_list[0] = "grape"

# %%
shopping_list
# Out:
# ['grape', 'banana', 'egg', 'bread', 100, 'noddle', 'orange']

# %%
shopping_list.insert(2, "milk")

# %%
shopping_list
# Out:
# ['grape', 'banana', 'milk', 'egg', 'bread', 100, 'noddle', 'orange']

# %%
## count items in list
len(shopping_list)
# Out:
# 8

# %%
## function vs. method
## OOP Object Oriented Programming

shopping_list.pop() ## remove the last element
# Out:
# 'orange'

# %%
shopping_list
# Out:
# ['grape', 'banana', 'milk', 'egg', 'bread', 100, 'noddle']

# %%
## remove specific item
shopping_list.remove("banana")

# %%
shopping_list
# Out:
# ['grape', 'milk', 'egg', 'bread', 100, 'noddle']

# %%
## add two lists together
item1 = ["banana",  "grape", "orange"]
item2 = ["milk", "bread"]

full_list = item1 + item2
print(full_list, len(full_list))
# Out:
# ['banana', 'grape', 'orange', 'milk', 'bread'] 5

# %%
full_list.sort(reverse = True) # reverse True is sort by z to a

# %%
full_list
# Out:
# ['orange', 'milk', 'grape', 'bread', 'banana']

# %%
## highlight how to use list
item1 = ["banana", "orange"]
item2 = item1.copy() ## mutable object

item1[0] = "longan"

print(item1, item2)
# Out:
# ['longan', 'orange'] ['banana', 'orange']

# %%
## tuple () very similar to list
## tuple is immutable; can't update value in it; ()
## while, list is mutable; can update value in it; []
friends = ("toy", "john", "mary")

# %%
friends.index("john")
# Out:
# 1

# %%
def hello():
    return 1,2,3,4,5 # tuple

# %%
hello()
# Out:
# (1, 2, 3, 4, 5)

# %%
type(hello())
# Out:
# tuple

# %%
def hello2():
    return [1,2,3,4,5]

# %%
hello2()
# Out:
# [1, 2, 3, 4, 5]

# %%
type(hello2())
# Out:
# list

# %%
def hello3():
    return {1,2,3,4,5}

# %%
type(hello3())
# Out:
# set

# %%
list_a = [1,2,3,4,5]
print(type(list_a))
# Out:
# <class 'list'>

# %%
## dictionary {}
## key-value pair ## extract data by key, can't by index
def hi():
    return "hi!"


toy = {
    "fname": "Kasidis",
    "lname": "Satangmongkol",
    "age": 35,
    "movie_lover": True,
    "education": "Master Degree",
    "fav_movies": ["The Dark Knight",
                   "Superman",
                   "Spiderman"],
    "function": hi
}

# %%
toy["fav_movies"][1]
# Out:
# 'Superman'

# %%
toy_func = toy["function"]

# %%
toy_func()
# Out:
# 'hi!'

# %%
## update value in dict
## dict is mutable
toy["fname"] = "John"
toy
# Out:
# {'fname': 'John',
#  'lname': 'Satangmongkol',
#  'age': 35,
#  'movie_lover': True,
#  'education': 'Master Degree',
#  'fav_movies': ['The Dark Knight', 'Superman', 'Spiderman'],
#  'function': <function __main__.hi()>}

# %%
## del key
del toy["lname"]

# %%
toy
# Out:
# {'fname': 'John',
#  'age': 35,
#  'movie_lover': True,
#  'education': 'Master Degree',
#  'fav_movies': ['The Dark Knight', 'Superman', 'Spiderman'],
#  'function': <function __main__.hi()>}

# %%
## create key
toy["lname"] = "Doe"

# %%
toy
# Out:
# {'fname': 'John',
#  'age': 35,
#  'movie_lover': True,
#  'education': 'Master Degree',
#  'fav_movies': ['The Dark Knight', 'Superman', 'Spiderman'],
#  'function': <function __main__.hi()>,
#  'lname': 'Doe'}

# %%
# get method by key if not found the key it will return blank not error
toy.get("fname")
# Out:
# 'John'

# %%
toy["fnameeee"] # if not use .get() then not found the key it will reture error

# %%
toy.get("happy world") # not found => reture blank

# %%
toy["school"] = "DataRockie"
toy
# Out:
# {'fname': 'Kasidis',
#  'lname': 'Satangmongkol',
#  'age': 35,
#  'movie_lover': True,
#  'education': 'Master Degree',
#  'fav_movies': ['The Dark Knight', 'Superman', 'Spiderman'],
#  'function': <function __main__.hi()>,
#  'school': 'DataRockie'}

# %%
## tuple list dictionary

## ? mutable -> list, dictionary
## ? immutable -> tuple

# %%
## set {unique set} => set will not return duplicate value
fruits = ["apple", "orange", "banana", "banana"]
type(fruits)
# Out:
# list

# %%
 uniq_set_fruits = set(fruits)

# %%
print(uniq_set_fruits,len(uniq_set_fruits), type(uniq_set_fruits))
# Out:
# {'orange', 'apple', 'banana'} 3 <class 'set'>
