# %% [markdown]
# # Project

# %% [markdown]
# # Final Project - Analyzing Sales Data
#
# **Date**: 21 November 2023
#
# **Author**: Saranpol Chakadkarn (Kanggie)
#
# **Course**: `Pandas Foundation`

# %%
# import data
import pandas as pd
df = pd.read_csv("sample-store.csv")

# %%
# preview top 5 rows
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# shape of dataframe
df.shape
# Out:
# (9994, 21)

# %%
# see data frame information using .info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          9994 non-null   int64
#  1   Order ID        9994 non-null   object
#  2   Order Date      9994 non-null   object
#  3   Ship Date       9994 non-null   object
#  4   Ship Mode       9994 non-null   object
#  5   Customer ID     9994 non-null   object
#  6   Customer Name   9994 non-null   object
#  7   Segment         9994 non-null   object
#  8   Country/Region  9994 non-null   object
#  9   City            9994 non-null   object
#  10  State           9994 non-null   object
#  11  Postal Code     9983 non-null   float64
#  12  Region          9994 non-null   object
#  13  Product ID      9994 non-null   object
#  14  Category        9994 non-null   object
#  15  Sub-Category    9994 non-null   object
#  16  Product Name    9994 non-null   object
# ...

# %% [markdown]
# We can use `pd.to_datetime()` function to convert columns 'Order Date' and 'Ship Date' to datetime.

# %%
# Convert Date format in "Order Date" and "Ship Date" from "%m/%d/%Y" to "2019-11-08 00:00:00"

df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# %%
# example of pd.to_datetime() function
import pandas as pd
df_test = pd.DataFrame()
df_test["new_order_date"] = pd.to_datetime(df['Order Date'], format='%m/%d/%Y')
df_test["new_ship_date"] = pd.to_datetime(df['Ship Date'], format='%m/%d/%Y')

df_test
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>new_order_date</th>
#       <th>new_ship_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2019-11-08</td>
#       <td>2019-11-11</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019-11-08</td>
#       <td>2019-11-11</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2019-06-12</td>
#       <td>2019-06-16</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2018-10-11</td>
#       <td>2018-10-18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2018-10-11</td>
#       <td>2018-10-18</td>
#     </tr>
#     <tr>
#       <th>...</th>
# ...

# %%
# TODO - convert order date and ship date to datetime in the original dataframe
df_test["org_orderdate"] = df_test["new_order_date"].dt.strftime("%m/%d/%Y")
df_test["org_shipdate"] = df_test["new_ship_date"].dt.strftime("%m/%d/%Y")

df_test
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>new_order_date</th>
#       <th>new_ship_date</th>
#       <th>org_orderdate</th>
#       <th>org_shipdate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2019-11-08</td>
#       <td>2019-11-11</td>
#       <td>11/08/2019</td>
#       <td>11/11/2019</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2019-11-08</td>
#       <td>2019-11-11</td>
#       <td>11/08/2019</td>
#       <td>11/11/2019</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2019-06-12</td>
#       <td>2019-06-16</td>
#       <td>06/12/2019</td>
#       <td>06/16/2019</td>
#     </tr>
# ...

# %%
# TODO - count nan in postal code column
df.isna().sum() # from this line we know that "Postal Code" column have 11 missing value

# filter missing value in "Postal Code" column
df["Postal Code"][ df["Postal Code"].isna() ]
# Out:
# <pre>2234   NaN
# 5274   NaN
# 8798   NaN
# 9146   NaN
# 9147   NaN
# 9148   NaN
# 9386   NaN
# 9387   NaN
# 9388   NaN
# 9389   NaN
# 9741   NaN
# Name: Postal Code, dtype: float64</pre>

# %%
# TODO - filter rows with missing values
df_missing_value = df[df.isna().any(axis=1)]

df_missing_value
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2234</th>
# ...

# %%
df_without_missing = df[df.notna().all(axis=1)]

df_without_missing
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
# TODO - Explore this dataset on your owns, ask your own questions

#question: find total sales and total profit group by State
df.groupby(["State"])[ ["Sales", "Profit"] ].sum().reset_index()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>State</th>
#       <th>Sales</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alabama</td>
#       <td>19510.6400</td>
#       <td>5786.8253</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Arizona</td>
#       <td>35282.0010</td>
#       <td>-3427.9246</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Arkansas</td>
#       <td>11678.1300</td>
#       <td>4008.6871</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>California</td>
#       <td>457687.6315</td>
#       <td>76381.3871</td>
#     </tr>
#     <tr>
#       <th>4</th>
# ...

# %% [markdown]
# ## Data Analysis Part
#
# Answer 10 below questions to get credit from this course. Write `pandas` code to find answers.

# %%
# TODO 01 - how many columns, rows in this dataset
df.shape # 9994 rows, 21 columns
# Out:
# (9994, 21)

# %%
# TODO 02 - is there any missing values?, if there is, which colunm? how many nan values?
df_missing_value # there is 11 missing values (NaN) in "Postal Code" column
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2234</th>
# ...

# %%
# TODO 03 - your friend ask for `California` data, filter it and export csv for him
california = df[ df["State"] == "California" ]

california.to_csv("california.csv")

# %%
# TODO 04 - your friend ask for all order data in `California` and `Texas` in 2017 (look at Order Date), send him csv file

df["Order Date"] = pd.to_datetime(df["Order Date"])
#df[ (df["State"] == "California") | (df["State"] == "Texas") & (df["Order Date"].dt.year == 2017)]
TODO_04 = df[ (df["State"].isin(["California", "Texas"])) & (df["Order Date"].dt.year == 2017) ]

TODO_04.to_csv("TODO_04.csv")

TODO_04
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Row ID</th>
#       <th>Order ID</th>
#       <th>Order Date</th>
#       <th>Ship Date</th>
#       <th>Ship Mode</th>
#       <th>Customer ID</th>
#       <th>Customer Name</th>
#       <th>Segment</th>
#       <th>Country/Region</th>
#       <th>City</th>
#       <th>...</th>
#       <th>Postal Code</th>
#       <th>Region</th>
#       <th>Product ID</th>
#       <th>Category</th>
#       <th>Sub-Category</th>
#       <th>Product Name</th>
#       <th>Sales</th>
#       <th>Quantity</th>
#       <th>Discount</th>
#       <th>Profit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>5</th>
# ...

# %%
# TODO 05 - how much total sales, average sales, and standard deviation of sales your company make in 2017
#df[ df["Order Date"].dt.year == 2017 ].describe() this is code not include sum, so decided to use .agg()
df["Sales"][ df["Order Date"].dt.year == 2017 ].agg(["sum", "mean", "std"])
# sum sales = 484247.4981
# mean sales = 242.97415860511794
# std sales = 754.0533572593683
# Out:
# <pre>sum     484247.498100
# mean       242.974159
# std        754.053357
# Name: Sales, dtype: float64</pre>

# %%
# TODO 06 - which Segment has the highest profit in 2018
df[ df["Order Date"].dt.year == 2018 ].groupby("Segment")["Profit"].max()
#Consumer segment has the highest profit in 2018
# Out:
# <pre>Segment
# Consumer       3177.4750
# Corporate      2302.9671
# Home Office    1906.4850
# Name: Profit, dtype: float64</pre>

# %%
# TODO 07 - which top 5 States have the least total sales between 15 April 2019 - 31 December 2019
df[ (df["Order Date"] >= "2019-04-15") & (df["Order Date"] <= "2019-12-31") ]\
    .groupby("State")["Sales"]\
        .agg("sum")\
            .sort_values()

# New Hampshire < New Mexico < District of Columbia < Louisiana < South Carolina
# Out:
# <pre>State
# New Hampshire               49.0500
# New Mexico                  64.0800
# District of Columbia       117.0700
# Louisiana                  249.8000
# South Carolina             502.4800
# Maine                      547.3300
# Kansas                     691.0600
# Iowa                       959.3100
# Idaho                     1148.8060
# Delaware                  1462.9500
# Minnesota                 1463.9400
# Maryland                  1541.0120
# Wyoming                   1603.1360
# Utah                      1822.4100
# Tennessee                 1889.0060
# Arkansas                  2008.3500
# Nebraska                  3081.4200
# Massachusetts             3489.7340
# Missouri                  3523.9500
# Connecticut               3605.6000
# Kentucky                  3912.6100
# Mississippi               4669.3500
# Arizona                   4713.9330
# Oregon                    4914.9600
# Oklahoma                  5047.6800
# ...

# %%
# TODO 08 - what is the proportion of total sales (%) in West + Central in 2019 e.g. 25%

# filterd West and Central data
filterd_west_central = df[ (df["Order Date"].dt.year == 2019) & (df["Region"].isin(["West", "Central"])) ]

# find the total sales for West and Central
total_sale_inWestCentral = filterd_west_central.groupby("Region")["Sales"].agg("sum").sum()

# find the total sales for all regions
total_sale_allRegion = df[ (df["Order Date"].dt.year == 2019) ].groupby("Region")["Sales"].agg("sum").sum()

# Calculate proportion of total sales in West and Central
Proportion_west_central = (total_sale_inWestCentral / total_sale_allRegion) * 100

print(f"Proportion of total sales in West and Central is {Proportion_west_central:.2f}%")
# Out:
# Proportion of total sales in West and Central is 54.97%

# %%
# TODO 09 - find top 10 popular products in terms of number of orders vs. total sales during 2019-2020

# filtered data between 2019-2020
filtered_2019_2020 = df[ (df["Order Date"].dt.year >= 2019) & (df["Order Date"].dt.year <= 2020) ]

# Top 10 product of number of orders
top10_number_orders = filtered_2019_2020.groupby("Product Name").agg({"Order ID":"count"}).sort_values(by="Order ID", ascending=False).head(10).reset_index()

print(top10_number_orders)

# Top 10 product that total sales during 2019-2020
top10_total_sales = filtered_2019_2020.groupby("Product Name").agg({"Sales":"sum"}).sort_values(by="Sales", ascending=False).head(10).reset_index()

print(top10_total_sales)
# Out:
#                                       Product Name  Order ID
# 0                                Easy-staple paper        27
# 1                                          Staples        24
# 2                                  Staple envelope        22
# 3                          Staples in misc. colors        13
# 4                                   Staple remover        12
# 5                          Storex Dura Pro Binders        12
# 6               Chromcraft Round Conference Tables        12
# 7  Global Wood Trimmed Manager's Task Chair, Khaki        11
# 8                          Avery Non-Stick Binders        11
# 9                       Staple-based wall hangings        10
#                                         Product Name      Sales
# 0              Canon imageCLASS 2200 Advanced Copier  61599.824
# 1               Hewlett Packard LaserJet 3310 Copier  16079.732
# 2   3D Systems Cube Printer, 2nd Generation, Magenta  14299.890
# ...

# %%
# TODO 10 - plot at least 2 plots, any plot you think interesting :)

import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with the specified columns
# Convert 'Order Date' and 'Ship Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# Plot 1: Scatter Plot of Sales vs. Profit
plt.figure(figsize=(12, 8))
plt.scatter(df['Sales'], df['Profit'], alpha=0.5, color='orange')
plt.title('Scatter Plot of Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# Plot 2: Scatter Plot of Sales vs. Profit (group by Category)
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.scatterplot(data=df, x='Sales', y='Profit', hue='Category', palette='viridis', alpha=0.7)
plt.title('Sales vs. Profit Scatter Plot')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
# TODO Bonus - use np.where() to create new column in dataframe to help you answer your own questions

import pandas as pd
import numpy as np

# Assuming df is your DataFrame with the specified columns
# Convert 'Order Date' and 'Ship Date' to datetime format
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])

# Set a threshold for high sales (you can adjust this based on your criteria)
sales_threshold = 1000

# Create a new column "High_Sales" using np.where()
df['High_Sales'] = np.where(df['Sales'] > sales_threshold, 'High', 'Low')

# Display the DataFrame with the new column
print(df[['Sales', 'High_Sales']].head())
# Out:
#       Sales High_Sales
# 0  261.9600        Low
# 1  731.9400        Low
# 2   14.6200        Low
# 3  957.5775        Low
# 4   22.3680        Low
